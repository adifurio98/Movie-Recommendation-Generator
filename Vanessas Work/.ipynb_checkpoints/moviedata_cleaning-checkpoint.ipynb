# %%
#Import Data Science Libs
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Import the data - Movies Metadata
movdf = pd.read_csv("moviedata/movies_metadata1.csv")
movdf.head()
# Out:
#      budget                                             genres     id  \
# 0  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...    862
# 1  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844
# 2         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602
# 3  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357
# 4         0                     [{'id': 35, 'name': 'Comedy'}]  11862
#
#      imdb_id original_language               original_title  popularity  \
# 0  tt0114709                en                    Toy Story   21.946943
# 1  tt0113497                en                      Jumanji   17.015539
# 2  tt0113228                en             Grumpier Old Men   11.712900
# 3  tt0114885                en            Waiting to Exhale    3.859495
# 4  tt0113041                en  Father of the Bride Part II    8.387519
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# ...

# %%
movdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45463 entries, 0 to 45462
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                45463 non-null  int64
#  1   genres                45463 non-null  object
#  2   id                    45463 non-null  int64
#  3   imdb_id               45446 non-null  object
#  4   original_language     45452 non-null  object
#  5   original_title        45463 non-null  object
#  6   popularity            45460 non-null  float64
#  7   production_companies  45460 non-null  object
#  8   production_countries  45460 non-null  object
#  9   release_date          45376 non-null  object
#  10  revenue               45460 non-null  float64
#  11  runtime               45203 non-null  float64
#  12  spoken_languages      45460 non-null  object
#  13  title                 45460 non-null  object
#  14  vote_average          45460 non-null  float64
# ...

# %%
movdf.genres.value_counts()
# Out:
# [{'id': 18, 'name': 'Drama'}]                                                                                                                                                                          5000
# [{'id': 35, 'name': 'Comedy'}]                                                                                                                                                                         3621
# [{'id': 99, 'name': 'Documentary'}]                                                                                                                                                                    2723
# []                                                                                                                                                                                                     2442
# ...

# %%
# Reducing the Genre data to just one type
movdf['genres'] = movdf.genres.apply(lambda x: x.split(",")[0])
movdf.head()
# Out:
#      budget         genres     id    imdb_id original_language  \
# 0  30000000     [{'id': 16    862  tt0114709                en
# 1  65000000     [{'id': 12   8844  tt0113497                en
# 2         0  [{'id': 10749  15602  tt0113228                en
# 3  16000000     [{'id': 35  31357  tt0114885                en
# 4         0     [{'id': 35  11862  tt0113041                en
#
#                 original_title  popularity  \
# 0                    Toy Story   21.946943
# 1                      Jumanji   17.015539
# 2             Grumpier Old Men   11.712900
# 3            Waiting to Exhale    3.859495
# 4  Father of the Bride Part II    8.387519
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3  [{'name': 'Twentieth Century Fox Film Corporat...
# ...

# %%
# Reducing the production_companies data to just one type
movdf['production_companies'] = movdf['production_companies'].apply(lambda x: x.split(",")[0])
movdf.head()

# %%
# Reducing the production_countries data to just one type
movdf['production_countries'] = movdf['production_countries'].apply(lambda x: x.split(",")[0])
movdf.head()

# %%
# Reducing the spoken_languages data to just one type
movdf['spoken_languages'] = movdf['spoken_languages'].apply(lambda x: x.split(",")[0])
movdf.head()

# %%
# Convert data to proper types.

movdf['budget'] = movdf['budget'].astype(int)
movdf['id'] = movdf['id'].astype(int)
movdf['popularity'] = movdf['popularity'].astype(float)
movdf['release_date'] = movdf['release_date'].to_datetime()

movdf.head()
